# %%
import numpy as np

# %%
#inputs
L =  0.7267474369 #m
x = 0.5720417245 #m
h5 = 0.52 #m
h0 = 0.98 #m
g = 9.81 #m/s^2
q = 48*np.pi/180

# %%
#calculations
Vox = np.sqrt(2*g*(h0-h5))*np.cos(q)
Voy = np.sqrt(2*g*(h0-h5))*np.sin(q)
y0 = h5

d1 = (Voy/g) * (Voy - np.sqrt(Voy**2 + 2*y0*g))
d2 = (Voy/g) * (Voy + np.sqrt(Voy**2 + 2*y0*g))

print(f"Distance 1 = {d1:.4g}")
print(f"Distance 2 = {d2:.4g}")
# Out:
# Distance 1 = -0.3788
# Distance 2 = 1.395
