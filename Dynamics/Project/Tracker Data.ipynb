# %%
import numpy as np
import matplotlib.pyplot as plt

tracker_data = np.genfromtxt("Tracker.txt",delimiter=",",skip_header=2)
tracker_data = np.nan_to_num(tracker_data, nan=0.0)

t = tracker_data[:, 0]
x = tracker_data[:, 1]
y = tracker_data[:, 2]
